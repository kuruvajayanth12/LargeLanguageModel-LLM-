# %% [markdown]
# <a href="https://colab.research.google.com/github/kuruvajayanth12/LargeLanguageModel-LLM-/blob/main/Question_Answering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers torch

# %%
# Install required libraries
# pip install transformers torch

from transformers import pipeline

# Load pre-trained Question Answering model
qa_model = pipeline(
    "question-answering",
    model="distilbert-base-cased-distilled-squad"
)

# Take context from user
context = input("\nEnter the context paragraph:\n")

# Take question from user
question = input("\nEnter your question:\n")

# Get answer
result = qa_model(
    question=question,
    context=context
)

# Print answer
print("\nAnswer:", result["answer"])
# Out:
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
# Enter the context paragraph:
# Machine Learning is a branch of Artificial Intelligence that focuses on enabling computers to learn from data and improve their performance without being explicitly programmed. It uses algorithms to identify patterns, make predictions, and support decision-making based on past experiences. Machine learning is widely applied in areas such as healthcare, finance, recommendation systems, image recognition, and natural language processing, making systems smarter and more efficient over time.
#
# Enter your question:
# what are different ML applications
#
# Answer: healthcare, finance, recommendation systems, image recognition, and natural language processing
